# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb:27017')
client
# Out:
# MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'contracts', 'local', 'sampledb']

# %%
client = MongoClient('mongodb:27017')
db = client.contracts['Submission']

# %%
list(db.find({"ID":"32324e3r§"}, {'datasets.data':1, "_id":0}))[0]
# Out:
# {'datasets': [{'data': '[{"col 0":0.8052051999,"col 1":-0.2619635714,"col 2":1.5003302246,"col 3":0.5396478929,"col 4":-2.0230302791,"col 5":-1.5041613999,"col 6":-0.1908598788,"col 7":-1.4268289335,"col 8":-1.225153832,"col 9":2.2823910135,"col 10":-0.4770953439,"col 11":-0.8763408566,"col 12":-0.6618260727,"col 13":1.1559531938,"col 14":-1.1465541861,"col 15":-0.0791368784,"col 16":0.1845423778,"col 17":1.572964753,"col 18":1.1990296298,"col 19":-1.7983969817},{"col 0":0.6964784806,"col 1":-0.7030287161,"col 2":0.0392626369,"col 3":-1.1684809314,"col 4":0.3886984841,"col 5":-1.0211569791,"col 6":2.105657188,"col 7":1.0774024616,"col 8":0.3100334765,"col 9":-1.0030530911,"col 10":0.4264434334,"col 11":0.0067657613,"col 12":-1.9478570484,"col 13":0.0657839395,"col 14":0.7873885213,"col 15":0.8531404462,"col 16":-1.5033930609,"col 17":0.7324658121,"col 18":0.0201060218,"col 19":0.6671855258},{"col 0":1.1600878352,"col 1":-0.2335452152,"col 2":0.2778127267,"col 3":1.9548146447,"col 4":-0.2672540796,"col 5":-1.6700620865,"col 6":-1.2665823438,"col 7":0.8987998611,"col 8":-0.6064061995,"col 9":2.1271151369,"col 10":0.0820341357,"col 11":0.4362672079,"col 12":-0.4872992061,"col 13":-0.1366874665,"col 14":0.9243316822,"col 15":-1.7050228255,"col 16":0.1705489463,"col 17":0.0885750604,"col 18":0.2862716287,"col 19":0.8930522038},{"col 0":-0.5601385982,"col 1":-0.1002245593,"col 2":0.2981872823,"col 3":0.0411770563,"col 4":0.8467823539,"col 5":0.6972340536,"col 6":-0.5944584037,"col 7":-1.0275769656,"col 8":0.2464877783,"col 9":-1.0566137191,"col 10":-1.0114795576,"col 11":0.7910472876,"col 12":0.4162028044,"col 13":-0.1110224366,"col 14":1.3896699564,"col 15":-0.678792475,"col 16":-0.3508239508,"col 17":0.8820270619,"col 18":0.817656511,"col 19":1.2950685513},{"col 0":0.4800593911,"col 1":0.5985990499,"col 2":0.272416098,"col 3":-0.8683119108,"col 4":-0.1031131787,"col 5":-0.5163952697,"col 6":-0.0956506888,"col 7":-0.0999844443,"col 8":-0.7615240859,"col 9":0.7867350633,"col 10":-0.8667537692,"col 11":0.4902213132,"col 12":0.9527451166,"col 13":1.5047425418,"col 14":-1.0368073129,"col 15":-0.594428666,"col 16":0.819617722,"col 17":0.3733408843,"col 18":-0.4251165336,"col 19":2.4418987463},{"col 0":0.0613105444,"col 1":0.5804128476,"col 2":-0.2642153599,"col 3":0.8948688435,"col 4":-1.8167841669,"col 5":-0.0031740647,"col 6":1.5698017564,"col 7":-1.570235613,"col 8":0.7366280488,"col 9":1.7428302055,"col 10":0.3830510177,"col 11":-1.5452036144,"col 12":0.7151226106,"col 13":-0.8030677134,"col 14":0.142777497,"col 15":-0.0472740327,"col 16":0.9679208774,"col 17":1.7038337114,"col 18":-1.2724779551,"col 19":-0.5312263269},{"col 0":0.4752476226,"col 1":-2.1104747563,"col 2":0.8830083136,"col 3":-1.1078497086,"col 4":-0.6923359658,"col 5":-0.130645622,"col 6":-0.3311677568,"col 7":-0.2208455507,"col 8":-0.1430913587,"col 9":1.0826120179,"col 10":-0.6205331999,"col 11":-0.6350596655,"col 12":-0.5361441001,"col 13":-0.5135878815,"col 14":-0.5498674274,"col 15":-1.2482157817,"col 16":1.0148721795,"col 17":-0.2412147905,"col 18":2.0445746969,"col 19":0.6395142359},{"col 0":-0.5083397346,"col 1":-1.1639002188,"col 2":-0.9148838262,"col 3":-0.030715045,"col 4":0.5161386541,"col 5":1.3587874029,"col 6":-1.6462263941,"col 7":-1.1843088211,"col 8":0.7106761945,"col 9":-0.6469583042,"col 10":-1.3556652665,"col 11":0.0912232712,"col 12":-0.4419596734,"col 13":0.1933897809,"col 14":0.8118184376,"col 15":-0.7288727247,"col 16":-1.0558299037,"col 17":0.0932294487,"col 18":1.2561996013,"col 19":-1.0485375762},{"col 0":0.8914680521,"col 1":0.2961939784,"col 2":-0.2980115699,"col 3":-1.7432207048,"col 4":1.1052977198,"col 5":-1.1183740469,"col 6":2.0347497447,"col 7":-1.5657094914,"col 8":0.3243698525,"col 9":-0.3678531514,"col 10":-0.3439627708,"col 11":0.5952449737,"col 12":-0.6529506724,"col 13":-0.8035976019,"col 14":0.8517949588,"col 15":0.5442042095,"col 16":-0.6114032824,"col 17":-1.0072479004,"col 18":1.0865633742,"col 19":0.0809726191},{"col 0": ...

# %%
client.contracts['Submission'].find({"UW Year": 2020})[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 client.contracts['Submission'].find({"UW Year": 2020})[2]
#
# File /usr/local/lib/python3.11/site-packages/pymongo/cursor.py:760, in Cursor.__getitem__(self, index)
#     758     for doc in clone:
#     759         return doc
# --> 760     raise IndexError("no such item for Cursor instance")
#     761 raise TypeError("index %r cannot be applied to Cursor instances" % index)
#
# IndexError: no such item for Cursor instance

# %%
db = client.sampledb
db
# Out:
# Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'sampledb')

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
student_collection = db["students"]
student_collection
# Out:
# Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'sampledb'), 'students')

# %%
student1 = { "name": "John", "age": 10, "class": "VI", "section": "A" }
result = student_collection.insert_one(student1)
result

# %%
print(f"Inserted new record id: {result.inserted_id}")
# Out:
# Inserted new record id: 63bc818e2ec6ecd8e99120ee

# %%
for student in student_collection.find():
    print(student)
# Out:
# {'_id': ObjectId('63bc818e2ec6ecd8e99120ee'), 'name': 'John', 'age': 10, 'class': 'VI', 'section': 'A'}

# %%
import pandas as pd
students = student_collection.find()
students

# %%
students = [
    { "name": "Maria", "age": 9, "class": "VI", "section": "B"},
    { "name": "Michel", "age": 11, "class": "VII", "section": "A"},
    { "name": "Priyanka", "age": 8, "class": "IV", "section": "B"},
    { "name": "Jeena", "age": 12, "class": "X", "section": "A" }
]

# %%
result = student_collection.insert_many(students)
result

# %%
import pandas as pd
students = student_collection.find()
students

# %%
list_students = list(students)
list_students
# Out:
# [{'_id': ObjectId('63bc818e2ec6ecd8e99120ee'),
#   'name': 'John',
#   'age': 10,
#   'class': 'VI',
#   'section': 'A'},
#  {'_id': ObjectId('63bc81962ec6ecd8e99120ef'),
#   'name': 'Maria',
#   'age': 9,
#   'class': 'VI',
#   'section': 'B'},
#  {'_id': ObjectId('63bc81962ec6ecd8e99120f0'),
#   'name': 'Michel',
#   'age': 11,
#   'class': 'VII',
#   'section': 'A'},
#  {'_id': ObjectId('63bc81962ec6ecd8e99120f1'),
#   'name': 'Priyanka',
#   'age': 8,
#   'class': 'IV',
#   'section': 'B'},
#  {'_id': ObjectId('63bc81962ec6ecd8e99120f2'),
#   'name': 'Jeena',
#   'age': 12,
#   'class': 'X',
#   'section': 'A'}]

# %%
pd.DataFrame(list_students)
# Out:
#                         _id      name  age class section
# 0  63bc818e2ec6ecd8e99120ee      John   10    VI       A
# 1  63bc81962ec6ecd8e99120ef     Maria    9    VI       B
# 2  63bc81962ec6ecd8e99120f0    Michel   11   VII       A
# 3  63bc81962ec6ecd8e99120f1  Priyanka    8    IV       B
# 4  63bc81962ec6ecd8e99120f2     Jeena   12     X       A

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))

# %%
df_collection = db["df"]
df_collection
# Out:
# Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'sampledb'), 'df')

# %%
df_collection.insert_one({'title': 'DF', 'df': df.to_json(orient='records')})

# %%
pd.DataFrame(list(df_collection.find()))
# Out:
#                         _id title  \
# 0  63bc84b42ec6ecd8e99120f3    DF
#
#                                                   df
# 0  [{"A":1.3083816802,"B":-0.2796342766,"C":-0.93...
